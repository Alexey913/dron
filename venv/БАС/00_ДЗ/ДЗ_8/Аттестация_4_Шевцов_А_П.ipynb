# %% [markdown]
# # Обеспечение качества и безопасности данных в системах машинного зрения

# %% [markdown]
# ## Кейс:

# %% [markdown]
# Вы работаете инженером машинного зрения в сфере БАС. Руководство Вашего подразделения попросило передать мини-датасет изображений и сопутствущую телеметрию субподрядчику для выполнения заказанных работ. Вы знаете что:
# - для работы им нужны только некторые данные в телеметрии — а именно данные по динамике полета (высота, углы…);
# - у них система «заточена» под общий формат (стандарт телеметрии для БАС данного типа дататсетов): строго определенное число столбцов и навазния столбцов, при этом ячейки не должны быть пустыми (или содержать значения, интерпретируемые как пустые — пустые строки, например). Ваш файл телеметри полностью соответствует стандарту;
# - помните случай в прошлом году, когда утечка координат и времени полета из файла телемеитрии БАС-опрератора «Компании X» привела ее к серьезным убыткам;
# - не знаете никого в организации субподрядчика и в первый раз с ними работате…
#
# Проявляя разумную осмотрительность на этапе передачи данных, Вы решаете (предварительно договрившись с субподрядчиком использовать защищенный протокол передачи данных, например SSH):
# 1. Зашифровать столбцы телеметрии с данными координат и времени полета.
# 2. Удалить все EXIF-метаданные изображений

# %% [markdown]
# ## Для этого Вам надо:

# %% [markdown]
# 1. Прочитать датасет в pandas и зашифровать соотвеотствующие данные, а также
# 2. Написать функцию, которая будет копировать изображения в другую директорию, но уже
# без метаданных.

# %% [markdown]
# ## Материал для выполнения:

# %% [markdown]
# __Архив, содержащий:__
# 1. Набор из нескольких изображений с метаданными «0001.jpg, 0002.jpg...»
# 2. Файл фрагмента телеметрии БАС «tele_part.xlsx»

# %% [markdown]
# ## Работа над кейсом

# %% [markdown]
# ### 1. Импорт необходимых библиотек

# %%
import pandas as pd
import hashlib as hl
import PIL.Image as im
import PIL.ExifTags as tags
import os
from exif import Image as exim

# %% [markdown]
# ### 2. Шифрование (кэширование) данных телеметрии

# %% [markdown]
# __Загрузка данных в pandas__

# %%
file_name = 'telemetry.csv'

ds = pd.read_csv(file_name)
ds.head()
# Out:
#           image        date         time        lat        lon    alt  pitch  \
# 0  DSC00003.JPG  2020/04/30  04:47:07,00  61.521366  30.339928   18.3    0.5
# 1  DSC00004.JPG  2020/04/30  04:47:07,00  61.521366  30.339928   18.3    0.5
# 2  DSC00005.JPG  2020/04/30  04:47:09,00  61.521366  30.339930   18.4    0.6
# 3  DSC00006.JPG  2020/04/30  04:47:10,00  61.521366  30.339931   18.6    0.6
# 4  DSC00007.JPG  2020/04/30  05:00:10,00  61.503338  30.437277  295.6    0.7
#
#    roll  azimuth  GPS_speed
# 0   0.0    140.0       0.00
# 1   0.0    140.0       0.00
# 2  -0.4    140.0       0.00
# 3  -0.5    140.0       0.00
# 4   1.8     97.0      81.36

# %% [markdown]
# __Функция хэширования__

# %% [markdown]
# * Используем функцию хэширования для значения ячеек столбца column и строки row
# * Значение предварительно переводим в строчный формат, т.к. формат float, имеющийся в ячейках не будет кодироваться

# %%
def hash_data(column, row):
    return hl.sha256(str(row[column]).encode('utf-8')).hexdigest()

# %% [markdown]
# __Функция замены данных в наборе данных__

# %% [markdown]
# * Функция для построчного хеширования данных конкретного столбца реализуется с помощью метода apply в pandas
# * Используем значение axis=1, что означаетпострочный обход столбца column
# * Используем лямбда-функцию - значение номера строки в данном случае будет изменяться в соответствии с проходом метода apply.

# %%
def replace_data(column):
    ds[column] = ds.apply(lambda x: hash_data(column, x), axis=1)

# %% [markdown]
# __Кэшируем данные, не касающиеся динамики полета__

# %% [markdown]
# * Определяем параметры, которые необходимо оставить без изменений - согласно кейсу, характеристики, касающиеся полета.
# * Остальные парметры хэшируем - итеративно хэшируем каждый столбец, за исключением определнных выше

# %%
fly_params = ['alt', 'pitch', 'roll', 'GPS_speed']
for col in ds.columns.tolist():
    if not col in fly_params:
        replace_data(col)
ds.head()
# Out:
#                                                image  \
# 0  6f85111652d5c6ea9d772b918efdb2a96aa043e220291c...
# 1  1dd31e027c4ccc0ed487fbd94d6a21471796395bafa191...
# 2  1b16eb81f45d75e58586785b4cbdc4d1123c022be92ee9...
# 3  814ebc56bd745831bbfe037ea29812251e0e45c14798fe...
# 4  80bf56b54251fc94d8803c8dae1a6a15281f8411a2f599...
#
#                                                 date  \
# 0  5fc67389af8980a2d483c93d15f1a99509d1a960867825...
# 1  5fc67389af8980a2d483c93d15f1a99509d1a960867825...
# 2  5fc67389af8980a2d483c93d15f1a99509d1a960867825...
# 3  5fc67389af8980a2d483c93d15f1a99509d1a960867825...
# 4  5fc67389af8980a2d483c93d15f1a99509d1a960867825...
#
#                                                 time  \
# 0  56e6708a2f0be9a25986b1c8290b2fbec50fccf9539fa9...
# 1  56e6708a2f0be9a25986b1c8290b2fbec50fccf9539fa9...
# 2  3b002224be6aceba1e9a7c713f7bae25edc96672e04de0...
# 3  b07c6a4a0e88130a58156a6829b72179372870a13cf532...
# 4  82ab96936882be49edb3fe7e5fef2c79380e58a1343ea9...
#
#                                                  lat  \
# 0  3090639c79c3272d7bf2e2946eb6958b4b2e26fbb4d7e9...
# 1  3090639c79c3272d7bf2e2946eb6958b4b2e26fbb4d7e9...
# 2  3090639c79c3272d7bf2e2946eb6958b4b2e26fbb4d7e9...
# 3  3090639c79c3272d7bf2e2946eb6958b4b2e26fbb4d7e9...
# 4  dd032c26f37c77f1ae378ae4dcbdae1b06a279c4771cac...
#
#                                                  lon    alt  pitch  roll  \
# 0  496b4ff3781ed341f5c3c43ad0bdc6b681833214dfb5b5...   18.3    0.5   0.0
# 1  496b4ff3781ed341f5c3c43ad0bdc6b681833214dfb5b5...   18.3    0.5   0.0
# 2  3df635a9c1c8720af19592df83ae438b2ddf8ab1b1a892...   18.4    0.6  -0.4
# 3  ffc95fea2f89c53d5ccb697700832ccb60fb69f36fa708...   18.6    0.6  -0.5
# 4  ce22e62b0cb7ed1e2f0ead97e220e06a59a2a140df7cec...  295.6    0.7   1.8
#
#                                              azimuth  GPS_speed
# 0  5d6ba45ee1d5e1697ad5f130677d44a7812ad273f13d6c...       0.00
# 1  5d6ba45ee1d5e1697ad5f130677d44a7812ad273f13d6c...       0.00
# 2  5d6ba45ee1d5e1697ad5f130677d44a7812ad273f13d6c...       0.00
# 3  5d6ba45ee1d5e1697ad5f130677d44a7812ad273f13d6c...       0.00
# 4  ee36dd09533bf8d7521539ccdb78a2f0e74bf582742e79...      81.36

# %% [markdown]
# __Сохраняем датасет в новый csv-файл__

# %% [markdown]
# * Добавляем в название исходного файла строку '_hash'

# %%
new_file_name = "".join(file_name.split('.')[:-1])+'_hash.csv'
ds.to_csv(new_file_name)

# %% [markdown]
# __Проверка создания файла__

# %%
hash_ds = pd.read_csv(new_file_name)
hash_ds.head()
# Out:
#    Unnamed: 0                                              image  \
# 0           0  6f85111652d5c6ea9d772b918efdb2a96aa043e220291c...
# 1           1  1dd31e027c4ccc0ed487fbd94d6a21471796395bafa191...
# 2           2  1b16eb81f45d75e58586785b4cbdc4d1123c022be92ee9...
# 3           3  814ebc56bd745831bbfe037ea29812251e0e45c14798fe...
# 4           4  80bf56b54251fc94d8803c8dae1a6a15281f8411a2f599...
#
#                                                 date  \
# 0  5fc67389af8980a2d483c93d15f1a99509d1a960867825...
# 1  5fc67389af8980a2d483c93d15f1a99509d1a960867825...
# 2  5fc67389af8980a2d483c93d15f1a99509d1a960867825...
# 3  5fc67389af8980a2d483c93d15f1a99509d1a960867825...
# 4  5fc67389af8980a2d483c93d15f1a99509d1a960867825...
#
#                                                 time  \
# 0  56e6708a2f0be9a25986b1c8290b2fbec50fccf9539fa9...
# 1  56e6708a2f0be9a25986b1c8290b2fbec50fccf9539fa9...
# 2  3b002224be6aceba1e9a7c713f7bae25edc96672e04de0...
# 3  b07c6a4a0e88130a58156a6829b72179372870a13cf532...
# 4  82ab96936882be49edb3fe7e5fef2c79380e58a1343ea9...
#
#                                                  lat  \
# 0  3090639c79c3272d7bf2e2946eb6958b4b2e26fbb4d7e9...
# 1  3090639c79c3272d7bf2e2946eb6958b4b2e26fbb4d7e9...
# 2  3090639c79c3272d7bf2e2946eb6958b4b2e26fbb4d7e9...
# 3  3090639c79c3272d7bf2e2946eb6958b4b2e26fbb4d7e9...
# 4  dd032c26f37c77f1ae378ae4dcbdae1b06a279c4771cac...
#
#                                                  lon    alt  pitch  roll  \
# 0  496b4ff3781ed341f5c3c43ad0bdc6b681833214dfb5b5...   18.3    0.5   0.0
# 1  496b4ff3781ed341f5c3c43ad0bdc6b681833214dfb5b5...   18.3    0.5   0.0
# 2  3df635a9c1c8720af19592df83ae438b2ddf8ab1b1a892...   18.4    0.6  -0.4
# 3  ffc95fea2f89c53d5ccb697700832ccb60fb69f36fa708...   18.6    0.6  -0.5
# 4  ce22e62b0cb7ed1e2f0ead97e220e06a59a2a140df7cec...  295.6    0.7   1.8
#
#                                              azimuth  GPS_speed
# 0  5d6ba45ee1d5e1697ad5f130677d44a7812ad273f13d6c...       0.00
# 1  5d6ba45ee1d5e1697ad5f130677d44a7812ad273f13d6c...       0.00
# 2  5d6ba45ee1d5e1697ad5f130677d44a7812ad273f13d6c...       0.00
# 3  5d6ba45ee1d5e1697ad5f130677d44a7812ad273f13d6c...       0.00
# 4  ee36dd09533bf8d7521539ccdb78a2f0e74bf582742e79...      81.36

# %% [markdown]
# ### 3. Копирование изображений без метаданных

# %% [markdown]
# #### 3.1 Подготовка

# %% [markdown]
# __Сначала определяем все изображения из набора в список__

# %%
current_dir = os.path.abspath(os.curdir)
images = []
for f in os.scandir(current_dir):
    if f.is_file() and (
        f.path.split('.')[-1].lower() == 'jpg' or\
     f.path.split('.')[-1].lower() == 'jpeg'):
        images.append(f.path)
images
# Out:
# ['/home/alex/bpla/venv/БАС/00_ДЗ/ДЗ_8/2411.JPG',
#  '/home/alex/bpla/venv/БАС/00_ДЗ/ДЗ_8/338.JPG',
#  '/home/alex/bpla/venv/БАС/00_ДЗ/ДЗ_8/343.JPG',
#  '/home/alex/bpla/venv/БАС/00_ДЗ/ДЗ_8/1083.JPG']

# %% [markdown]
# __Проверим наличие метаданных на примере 1-го изображения из полученного списка__

# %% [markdown]
# * Загрузка изображения с помощью библиотеки Pillow

# %%
img = im.open(images[0])

# %% [markdown]
# * Выгружаем все имеющиеся метаданные изобржения в словарь

# %%
metadata = img._getexif()
metadata
# Out:
# {34853: {0: b'\x02\x00\x00\x00',
#   1: 'N',
#   2: (61.375687, 0.0, 0.0),
#   3: 'E',
#   4: (30.368956, 0.0, 0.0),
#   5: 0,
#   6: 291.6,
#   18: 'WGS-84'},
#  50341: b'PrintIM\x000300\x00\x00\x03\x00\x02\x00\x01\x00\x00\x00\x03\x00"\x00\x00\x00\x01\x01\x00\x00\x00\x00\t\x11\x00\x00\x10\'\x00\x00\x0b\x0f\x00\x00\x10\'\x00\x00\x97\x05\x00\x00\x10\'\x00\x00\xb0\x08\x00\x00\x10\'\x00\x00\x01\x1c\x00\x00\x10\'\x00\x00^\x02\x00\x00\x10\'\x00\x00\x8b\x00\x00\x00\x10\'\x00\x00\xcb\x03\x00\x00\x10\'\x00\x00\xe5\x1b\x00\x00\x10\'\x00\x00',
#  296: 2,
#  34665: 376,
#  270: '                               ',
#  271: 'SONY',
#  272: 'ILCE-6000',
#  305: 'ILCE-6000 v3.20',
#  274: 3,
#  306: '2020:04:30 08:48:36',
#  531: 2,
#  282: 350.0,
#  283: 350.0,
#  36864: b'0230',
#  37121: b'\x01\x02\x03\x00',
#  37122: 3.0,
#  36867: '2020:04:30 08:48:36',
#  36868: '2020:04:30 08:48:36',
#  37379: 6.45078125,
#  37380: 0.0,
#  37381: 1.6953125,
#  37383: 5,
#  37384: 0,
#  37385: 16,
#  37386: 35.0,
#  37510: b'',
#  40961: 1,
#  40962: 6000,
#  41990: 0,
#  40963: 4000,
#  41992: 0,
#  41993: 0,
#  41994: 0,
#  41728: b'\x03',
#  33434: 0.0015625,
#  40965: 19282,
#  33437: 2.2,
#  41729: b'\x01',
#  34850: 4,
#  41985: 0,
#  34855: 100,
#  41986: 0,
#  40960: b'0100',
#  34864: 2,
#  41987: 0,
#  34866: 100,
#  42034: (35.0, 35.0, 1.8, 1.8),
#  42036: 'E 35mm F1.8 OSS',
#  41988: 1.0,
#  41989: 52,
#  37500: b'SONY DSC \x00\x00\x00[\x00\x03\x10\x04\x00\x10\x00\x00\x00\xf8\x07\x00\x00\x00 \x07\x00\x01\x00\x00\x00\x00\x00\x00\x00\x02 \x04\x00\x01\x00\x00\x00\x00\x00\x00\x00\x03 \x02\x00\x00\x01\x00\x008\x08\x00\x00\x04 \t\x00\x01\x00\x00\x00\x00\x00\x00\x00\x05 \t\x00\x01\x00\x00\x00\x00\x00\x00\x00\x06 \t\x00\x01\x00\x00\x00\x00\x00\x00\x00\x07 \t\x00\x01\x00\x00\x00\x00\x00\x00\x00\x08 \x04\x00\x01\x00\x00\x00\x01\x00\x00\x00\t \x03\x00\x01\x00\x00\x00\x02\x00\x00\x00\n \x04\x00\x01\x00\x00\x00\x00\x00\x00\x00\x0c \x04\x00\x03\x00\x00\x008\t\x00\x00\r \x05\x00\x01\x00\x00\x00D\t\x00\x00\x14 \t\x00\x02\x00\x00\x00L\t\x00\x00\x000\x07\x00\x86\x01\x00\x00T\t\x00\x00 \xb0\x02\x00\x10\x00\x00\x00\xda\n\x00\x00!\xb0\x04\x00\x01\x00\x00\x00\x00\x00\x00\x00"\xb0\x04\x00\x01\x00\x00\x00\x00\x00\x00\x00#\xb0\x04\x00\x01\x00\x00\x00\x00\x00\x00\x00$\xb0\x04\x00\x01\x00\x00\x00\x00\x00\x00\x00%\xb0\x04\x00\x01\x00\x00\x00\x00\x00\x00\x00&\xb0\x04\x00\x01\x00\x00\x00\x01\x00\x00\x00)\xb0\x04\x00\x01\x00\x00\x00\x00\x00\x00\x00+\xb0\x04\x00\x02\x00\x00\x00\xea\n\x00\x00,\xb0\x04\x00\x02\x00\x00\x00\xf2\n\x00\x00\x00\xb0\x01\x00\x04\x00\x00\x00\x03\x03\x01\x00\x02\x01\x04\x00\x01\x00\x00\x00\x02\x00\x00\x00\x04\x01\n\x00\x01\x00\x00\x00\xfa\n\x00\x00\x12\x01\x04\x00\x01\x00\x00\x00\x00\x00\x00\x00\x15\x01\x04\x00\x01\x00\x00\x00\x00\x00\x00\x00\x01\xb0\x03\x00\x01\x00\x00\x008\x01\x00\x00\x05\x01\x04\x00\x01\x00\x00\x00\x00\x00\x00\x00\x0b \x04\x00\x01\x00\x00\x00\x00\x00\x00\x00\x0e \x03\x00\x01\x00\x00\x00\x00\x00\x00\x00\x0f \x04\x00\x01\x00\x00\x00\x00\x00\x00\x00\x11 \x04\x00\x01\x00\x00\x00\x02\x00\x00\x00\x12 \x04\x00\x01\x00\x00\x00\x02\x00\x00\x00\x13 \x04\x00\x01\x00\x00\x00\x00\x00\x00\x00\x15 \x03\x00\x01\x00\x00\x00\xff\xff\x00\x00\'\xb0\x04\x00\x01\x00\x00\x00\xff\xff\x00\x00*\xb0\x01\x00\x08\x00\x00\x00\x02\x0b\x00\x00\x16 \x03\x00\x01\x00\x00\x00\x00\x00\x00\x00\x17 \x04\x00\x01\x00\x00\x00\x00\x00\x00\x00\x18 \x04\x00\x01\x00\x00\x00\x00\x00\x00\x00\x19 \x04\x00\x01\x00\x00\x00\x00\x00\x00\x00\x1a \x04\x00\x01\x00\x00\x00\x01\x00\x00\x00\x1b \x01\x00\x01\x00\x00\x00\x00\x00\x00\x00\x1c \x01\x00\x01\x00\x00\x00\x01\x00\x00\x00\x1d \x03\x00\x02\x00\x00\x00\x00\x00\x00\x00\x1e \x01\x00\x01\x00\x00\x00\x00\x00\x00\x00\x1f \x01\x00\x04\x00\x00\x00\x00\x00\x00\x00  \x01\x00\n\x00\x00\x00\n\x0b\x00\x00! \x01\x00\x01\x00\x00\x00\x00\x00\x00\x00" \x01\x00\x1a\x00\x00\x00\x14\x0b\x00\x00# \x04\x00\x01\x00\x00\x00\x00\x00\x00\x00\x01P\x05\x00\x01\x00\x00\x00.\x0b\x00\x00\x02P\x01\x00\x01\x00\x00\x00\x80\x00\x00\x00A\xb0\x03\x00\x01\x00\x00\x00\x08\x00\x00\x00E\xb0\x03\x00\x01\x00\x00\x00\x00\x00\x00\x00F\xb0\x03\x00\x01\x00\x00\x00\x00\x00\x00\x00G\xb0\x03\x00\x01\x00\x00\x00\xff\xff\x00\x00H\xb0\x08\x00\x01\x00\x00\x00\x00\x00\x00\x00I\xb0\x03\x00\x01\x00\x00\x00\x00\x00\x00\x00J\xb0\x03\x00\x01\x00\x00\x00\x00\x00\x00\x00K\xb0\x03\x00\x01\x00\x00\x00\x02\x00\x00\x00L\xb0\x05\x00\x01\x00\x00\x006\x0b\x00\x00M\xb0\x03\x00\x01\x00\x00\x00\x00\x00\x00\x00O\xb0\x03\x00\x01\x00\x00\x00\x00\x00\x00\x00P\xb0\x03\x00\x01\x00\x00\x00\xff\xff\x00\x00Q\xb0\x03\x00\x01\x00\x00\x00\x00\x00\x00\x00R\xb0\x03\x00\x01\x00\x00\x00\x00\x00\x00\x00S\xb0\x03\x00\x01\x00\x00\x00\x00\x00\x00\x00T\xb0\x03\x00\x01\x00\x00\x00\x00\x00\x00\x00\x00\x94\x07\x00,\x02\x00\x00>\x0b\x00\x00\x01\x94\x07\x00\x00\x10\x00\x00j\r\x00\x00\x02\x94\x07\x00\x90\x01\x00\x00j\x1d\x00\x00\x03\x94\x07\x00\xe8\x03\x00\x00\xfa\x1e\x00\x00\x04\x94\x07\x00,\x02\x00\x00\xe2"\x00\x00\x05\x94\x07\x00\xc8\x07\x00\x00\x0e%\x00\x00\x06\x94\x07\x00@\x00\x00\x00\xd6,\x00\x00\x07\x94\x07\x00@\x00\x00\x00\x16-\x00\x00\x08\x94\x07\x00\xe8\x03\x00\x00V-\x00\x00\t\x94\x07\x00@\x05\x00\x00>1\x00\x00\n\x94\x07\x00\x10\x01\x00\x00~6\x00\x00\x0b\x94\x07\x00\x90\x01\x00\x00\x8e7\x00\x00\x0c\x94\x07\x00@\x00\x00\x00\x1e9\x00\x00\r\x94\x07\x00\xec\x04\x00\x00^9\x00\x00\x00\xa1\x07\x00@\x00\x00\x00J>\x00\x00\x0f\x94\x07\x00\x00\x08\x00\x00\x8a>\x00\x00P\x90\x07\x00\xb0\x03\x00\x00\x8aF\x00\x00\x12\x9 ...

# %% [markdown]
# * Чтобы понять, какая информация имеется в метаданных, используем сопоставление id тегов и их названий с помощью метода ExifTags.TAGS

# %%
exif_data = {
    tags.TAGS[k]: v
    for k, v in metadata.items()
    if k in tags.TAGS
}

exif_data
# Out:
# {'GPSInfo': {0: b'\x02\x00\x00\x00',
#   1: 'N',
#   2: (61.375687, 0.0, 0.0),
#   3: 'E',
#   4: (30.368956, 0.0, 0.0),
#   5: 0,
#   6: 291.6,
#   18: 'WGS-84'},
#  'PrintImageMatching': b'PrintIM\x000300\x00\x00\x03\x00\x02\x00\x01\x00\x00\x00\x03\x00"\x00\x00\x00\x01\x01\x00\x00\x00\x00\t\x11\x00\x00\x10\'\x00\x00\x0b\x0f\x00\x00\x10\'\x00\x00\x97\x05\x00\x00\x10\'\x00\x00\xb0\x08\x00\x00\x10\'\x00\x00\x01\x1c\x00\x00\x10\'\x00\x00^\x02\x00\x00\x10\'\x00\x00\x8b\x00\x00\x00\x10\'\x00\x00\xcb\x03\x00\x00\x10\'\x00\x00\xe5\x1b\x00\x00\x10\'\x00\x00',
#  'ResolutionUnit': 2,
#  'ExifOffset': 376,
#  'ImageDescription': '                               ',
#  'Make': 'SONY',
#  'Model': 'ILCE-6000',
#  'Software': 'ILCE-6000 v3.20',
#  'Orientation': 3,
#  'DateTime': '2020:04:30 08:48:36',
#  'YCbCrPositioning': 2,
#  'XResolution': 350.0,
#  'YResolution': 350.0,
#  'ExifVersion': b'0230',
#  'ComponentsConfiguration': b'\x01\x02\x03\x00',
#  'CompressedBitsPerPixel': 3.0,
#  'DateTimeOriginal': '2020:04:30 08:48:36',
#  'DateTimeDigitized': '2020:04:30 08:48:36',
#  'BrightnessValue': 6.45078125,
#  'ExposureBiasValue': 0.0,
#  'MaxApertureValue': 1.6953125,
#  'MeteringMode': 5,
#  'LightSource': 0,
#  'Flash': 16,
#  'FocalLength': 35.0,
#  'UserComment': b'',
#  'ColorSpace': 1,
#  'ExifImageWidth': 6000,
#  'SceneCaptureType': 0,
#  'ExifImageHeight': 4000,
#  'Contrast': 0,
#  'Saturation': 0,
#  'Sharpness': 0,
#  'FileSource': b'\x03',
#  'ExposureTime': 0.0015625,
#  'ExifInteroperabilityOffset': 19282,
#  'FNumber': 2.2,
#  'SceneType': b'\x01',
#  'ExposureProgram': 4,
#  'CustomRendered': 0,
#  'ISOSpeedRatings': 100,
#  'ExposureMode': 0,
#  'FlashPixVersion': b'0100',
#  'SensitivityType': 2,
#  'WhiteBalance': 0,
#  'RecommendedExposureIndex': 100,
#  'LensSpecification': (35.0, 35.0, 1.8, 1.8),
#  'LensModel': 'E 35mm F1.8 OSS',
#  'DigitalZoomRatio': 1.0,
#  'FocalLengthIn35mmFilm': 52,
#  'MakerNote': b'SONY DSC \x00\x00\x00[\x00\x03\x10\x04\x00\x10\x00\x00\x00\xf8\x07\x00\x00\x00 \x07\x00\x01\x00\x00\x00\x00\x00\x00\x00\x02 \x04\x00\x01\x00\x00\x00\x00\x00\x00\x00\x03 \x02\x00\x00\x01\x00\x008\x08\x00\x00\x04 \t\x00\x01\x00\x00\x00\x00\x00\x00\x00\x05 \t\x00\x01\x00\x00\x00\x00\x00\x00\x00\x06 \t\x00\x01\x00\x00\x00\x00\x00\x00\x00\x07 \t\x00\x01\x00\x00\x00\x00\x00\x00\x00\x08 \x04\x00\x01\x00\x00\x00\x01\x00\x00\x00\t \x03\x00\x01\x00\x00\x00\x02\x00\x00\x00\n \x04\x00\x01\x00\x00\x00\x00\x00\x00\x00\x0c \x04\x00\x03\x00\x00\x008\t\x00\x00\r \x05\x00\x01\x00\x00\x00D\t\x00\x00\x14 \t\x00\x02\x00\x00\x00L\t\x00\x00\x000\x07\x00\x86\x01\x00\x00T\t\x00\x00 \xb0\x02\x00\x10\x00\x00\x00\xda\n\x00\x00!\xb0\x04\x00\x01\x00\x00\x00\x00\x00\x00\x00"\xb0\x04\x00\x01\x00\x00\x00\x00\x00\x00\x00#\xb0\x04\x00\x01\x00\x00\x00\x00\x00\x00\x00$\xb0\x04\x00\x01\x00\x00\x00\x00\x00\x00\x00%\xb0\x04\x00\x01\x00\x00\x00\x00\x00\x00\x00&\xb0\x04\x00\x01\x00\x00\x00\x01\x00\x00\x00)\xb0\x04\x00\x01\x00\x00\x00\x00\x00\x00\x00+\xb0\x04\x00\x02\x00\x00\x00\xea\n\x00\x00,\xb0\x04\x00\x02\x00\x00\x00\xf2\n\x00\x00\x00\xb0\x01\x00\x04\x00\x00\x00\x03\x03\x01\x00\x02\x01\x04\x00\x01\x00\x00\x00\x02\x00\x00\x00\x04\x01\n\x00\x01\x00\x00\x00\xfa\n\x00\x00\x12\x01\x04\x00\x01\x00\x00\x00\x00\x00\x00\x00\x15\x01\x04\x00\x01\x00\x00\x00\x00\x00\x00\x00\x01\xb0\x03\x00\x01\x00\x00\x008\x01\x00\x00\x05\x01\x04\x00\x01\x00\x00\x00\x00\x00\x00\x00\x0b \x04\x00\x01\x00\x00\x00\x00\x00\x00\x00\x0e \x03\x00\x01\x00\x00\x00\x00\x00\x00\x00\x0f \x04\x00\x01\x00\x00\x00\x00\x00\x00\x00\x11 \x04\x00\x01\x00\x00\x00\x02\x00\x00\x00\x12 \x04\x00\x01\x00\x00\x00\x02\x00\x00\x00\x13 \x04\x00\x01\x00\x00\x00\x00\x00\x00\x00\x15 \x03\x00\x01\x00\x00\x00\xff\xff\x00\x00\'\xb0\x04\x00\x01\x00\x00\x00\xff\xff\x00\x00*\xb0\x01\x00\x08\x00\x00\x00\x02\x0b\x00\x00\x16 \x03\x00\x01\x00\x00\x00\x00\x00\x00\x00\x17 \x04\x00\x01\x00\x00\x00\x00\x00\x00\x00\x18 \x04\x00\x01\x00\x00\x00\x00\x00\x00\x00\x19 \x04\x00\x01\x00\x00\x00\x00\x00\x00\x00\x1a \x04\x00\x01\x00\x00\x00\x01\x00\x00\x00\x1b \x01\x00\x01\x00\x00\x00\x00\x00\x00\x00\x1c \x01\x00\x01\x00\x00\x00\x01\x00\x00\x00\x1d \x03\x00\x02\x00\x00\x00\x00\x00\x00\x00\x1e \x01\x00\x01\x00\x00\x00\x00\x00\x00\x00\x1f \x01\x00\x04\x00\x00\x00\x00\x00\x00\x00  \x01\x00\n\x00\x00\x00\n\x0b\x00\x00! \x01\x00\x01\x00\x00\x00\x00\x00\x00\x00" \x01\x00\x1a\x00\x00\x00\x14\x0b\x00\x00# \x04\x00\x01\x00\x00\x00\x00\x00\x00\x00\x01P\x05\x00\x01\x00\x00\x00.\x0b\x00\x00\x02P\x01\x00\x01\x00\x00\x00\x80\x00\x00\x00A\xb0\x03\x00\x01\x00\x00\x00\x08\x00\x00\x00E\xb0\x03\x00\x01\x00\x00\x00\x00\x00\x00\x00F\xb0\x03\x00\x01\x00\x00\x00\x00\x00\x00\x00G\xb0\x03\x00\x01\x00\x00\x00\xff\xff\x00\x00H\xb0\x08\x00\x01\x00\x00\x00\x00\x00\x00\x00I\xb0\x03\x00\x01\x00\x00\x00\x00\x00\x00\x00J\xb0\x03\x00\x01\x00\x00\x00\x00\x00\x00\x00K\xb0\x03\x00\x01\x00\x00\x00\x02\x00\x00\x00L\xb0\x05\x00\x01\x00\x00\x006\x0b\x00\x00M\xb0\x03\x00\x01\x00\x00\x00\x00\x00\x00\x00O\xb0\x03\x00\x01\x00\x00\x00\x00\x00\x00\x00P\xb0\x03\x00\x01\x00\x00\x00\xff\xff\x00\x00Q\xb0\x03\x00\x01\x00\x00\x00\x00\x00\x00\x00R\xb0\x03\x00\x01\x00\x00\x00\x00\x00\x00\x00S\xb0\x03\x00\x01\x00\x00\x00\x00\x00\x00\x00T\xb0\x03\x00\x01\x00\x00\x00\x00\x00\x00\x00\x00\x94\x07\x00,\x02\x00\x00>\x0b\x00\x00\x01\x94\x07\x00\x00\x10\x00\x00j\r\x00\x00\x02\x94\x07\x00\x90\x01\x00\x00j\x1d\x00\x00\x03\x94\x07\x00\xe8\x03\x00\x00\xfa\x1e\x00\x00\x04\x94\x07\x00,\x02\x00\x00\xe2"\x00\x00\x05\x94\x07\x00\xc8\x07\x00\x00\x0e%\x00\x00\x06\x94\x07\x00@\x00\x00\x00\xd6,\x00\x00\x07\x94\x07\x00@\x00\x00\x00\x16-\x00\x00\x08\x94\x07\x00\xe8\x03\x00\x00V-\x00\x00\t\x94\x07\x00@\x05\x00\x00>1\x00\x00\n\x94\x07\x00\x10\x01\x00\x00~6\x00\x00\x0b\x94\x07\x00\x90\x01\x00\x00\x8e7\x00\x00\x0c\x94\x07\x00@\x00\x00\x00\x1e9\x00\x00\r\x94\x07\x00\xec\x04\x00\x00^9\x00\x00\x00\xa1\x07\x00@\x00\x00\x00J>\x00\x00\x0f\x94\x07\x00\x00\x08\x00\x00\x8a>\x00\x00P\x90\x07\x00\xb0\x03\x00\x00\x8aF\x00\x00\ ...

# %% [markdown]
# #### 3.2 Удаление EXIF с помощью Pillow

# %% [markdown]
# __Функция создания нового изображения без метаданных__

# %%
def del_exif (input_img, savepth):
    img_name = input_img.split('/')[-1]
    img = im.open(input_img)

    data = list(img.getdata())
    image_without_exif = im.new(img.mode, img.size)
    image_without_exif.putdata(data)
    new_name = os.path.join(savepth, 'no_exif_' + img_name)
    image_without_exif.save(new_name)
    
    return f'exif cleared for {img_name}'

# %% [markdown]
# __Задаем директорию для сохранения изображений__

# %%
name_pth = 'no_exif'
if not os.path.exists(name_pth):
    os.mkdir(name_pth)
savepth = name_pth

# %% [markdown]
# __Применяем функцию удаления exif ко всем изображениям__

# %%
# %%time

for i in images:
    del_exif(i, savepth)
# Out:
# CPU times: user 46 s, sys: 7.33 s, total: 53.3 s
# Wall time: 53.7 s

# %% [markdown]
# __Проверяем наличие метаданных у новых изображений__

# %%
new_img_dir = os.path.join(os.path.abspath(os.curdir), savepth)
check_exif = []
for f in os.scandir(new_img_dir):
    temp = f.path
    img = im.open(f.path)
    check_exif.append(img._getexif())
check_exif
# Out:
# [None, None, None, None]

# %% [markdown]
# __Как виидим, функция получения метаданных вернула пустые словари для новых изображений__

# %% [markdown]
# #### 3.3 Удаление EXIF с помощью библиотеки EXIF

# %% [markdown]
# __Создадим словарь для загрузки объектов класса exif и название изображения. В нем ключами будут объекты класса exif, а значениями - названия__

# %%
exif_imgs = {}

# %% [markdown]
# __В цикле создаем экземпляры класса exif для всех изображений__

# %%
for i in images:
    with open(i, "rb") as img:
        img = exim(img)
    exif_imgs[img] = i.split('/')[-1]
exif_imgs
# Out:
# {<exif._image.Image at 0x7aef4cddd2e0>: '2411.JPG',
#  <exif._image.Image at 0x7aef4c246120>: '338.JPG',
#  <exif._image.Image at 0x7aef4c223740>: '343.JPG',
#  <exif._image.Image at 0x7aef4c220f20>: '1083.JPG'}

# %% [markdown]
# __Посмотрим, имеются ли теги у объектов, и какие__

# %%
for k in exif_imgs.keys():
    print(k.has_exif)
    print(dir(k))
# Out:
# True
# ['<unknown EXIF tag 50341>', '_exif_ifd_pointer', '_gps_ifd_pointer', '_interoperability_ifd_Pointer', '_segments', 'brightness_value', 'color_space', 'components_configuration', 'compressed_bits_per_pixel', 'compression', 'contrast', 'custom_rendered', 'datetime', 'datetime_digitized', 'datetime_original', 'delete', 'delete_all', 'digital_zoom_ratio', 'exif_version', 'exposure_bias_value', 'exposure_mode', 'exposure_program', 'exposure_time', 'f_number', 'file_source', 'flash', 'flashpix_version', 'focal_length', 'focal_length_in_35mm_film', 'get', 'get_all', 'get_file', 'get_thumbnail', 'gps_altitude', 'gps_altitude_ref', 'gps_latitude', 'gps_latitude_ref', 'gps_longitude', 'gps_longitude_ref', 'gps_map_datum', 'gps_version_id', 'has_exif', 'image_description', 'jpeg_interchange_format', 'jpeg_interchange_format_length', 'lens_model', 'lens_specification', 'light_source', 'list_all', 'make', 'maker_note', 'max_aperture_value', 'metering_mode', 'model', 'orientation', 'photographic_sensitivity', 'pixel_x_dimension', 'pixel_y_dimension', 'recommended_exposure_index', 'resolution_unit', 'saturation', 'scene_capture_type', 'scene_type', 'sensitivity_type', 'sharpness', 'software', 'user_comment', 'white_balance', 'x_resolution', 'y_and_c_positioning', 'y_resolution']
# True
# ['<unknown EXIF tag 50341>', '_exif_ifd_pointer', '_gps_ifd_pointer', '_interoperability_ifd_Pointer', '_segments', 'brightness_value', 'color_space', 'components_configuration', 'compressed_bits_per_pixel', 'compression', 'contrast', 'custom_rendered', 'datetime', 'datetime_digitized', 'datetime_original', 'delete', 'delete_all', 'digital_zoom_ratio', 'exif_version', 'exposure_bias_value', 'exposure_mode', 'exposure_program', 'exposure_time', 'f_number', 'file_source', 'flash', 'flashpix_version', 'focal_length', 'focal_length_in_35mm_film', 'get', 'get_all', 'get_file', 'get_thumbnail', 'gps_altitude', 'gps_altitude_ref', 'gps_latitude', 'gps_latitude_ref', 'gps_longitude', 'gps_longitude_ref', 'gps_map_datum', 'gps_version_id', 'has_exif', 'image_description', 'jpeg_interchange_format', 'jpeg_interchange_format_length', 'lens_model', 'lens_specification', 'light_source', 'list_all', 'make', 'maker_note', 'max_aperture_value', 'metering_mode', 'model', 'orientation', 'photographic_sensitivity', 'pixel_x_dimension', 'pixel_y_dimension', 'recommended_exposure_index', 'resolution_unit', 'saturation', 'scene_capture_type', 'scene_type', 'sensitivity_type', 'sharpness', 'software', 'user_comment', 'white_balance', 'x_resolution', 'y_and_c_positioning', 'y_resolution']
# True
# ['<unknown EXIF tag 50341>', '_exif_ifd_pointer', '_gps_ifd_pointer', '_interoperability_ifd_Pointer', '_segments', 'brightness_value', 'color_space', 'components_configuration', 'compressed_bits_per_pixel', 'compression', 'contrast', 'custom_rendered', 'datetime', 'datetime_digitized', 'datetime_original', 'delete', 'delete_all', 'digital_zoom_ratio', 'exif_version', 'exposure_bias_value', 'exposure_mode', 'exposure_program', 'exposure_time', 'f_number', 'file_source', 'flash', 'flashpix_version', 'focal_length', 'focal_length_in_35mm_film', 'get', 'get_all', 'get_file', 'get_thumbnail', 'gps_altitude', 'gps_altitude_ref', 'gps_latitude', 'gps_latitude_ref', 'gps_longitude', 'gps_longitude_ref', 'gps_map_datum', 'gps_version_id', 'has_exif', 'image_description', 'jpeg_interchange_format', 'jpeg_interchange_format_length', 'lens_model', 'lens_specification', 'light_source', 'list_all', 'make', 'maker_note', 'max_aperture_value', 'metering_mode', 'model', 'orientation', 'photographic_sensitivity', 'pixel_x_dimension', 'pixel_y_dimension', 'recommended_exposure_index', 'resolution_unit', 'saturation', 'scene_capture_type', 'scene_type', 'sensitivity_type', 'sharpness', 'software', 'user_comment', 'white_balance', 'x_resolution', 'y_and_c_positioning', 'y_resolution']
# True
# ['<unknown EXIF tag 50341>', '_exif_ifd_pointer', '_gps_ifd_pointer', '_interoperability_ifd_Pointer', '_segments', 'brightness_value', 'color_space', 'components_configuration', 'compressed_bits_per_pixel', 'compression', 'contrast', 'custom_rendered', 'datetime', 'datetime_digitized', 'datetime_original', 'delete', 'delete_all', 'digital_zoom_ratio', 'exif_version', 'exposure_bias_value', 'exposure_mode', 'exposure_program', 'exposure_time', 'f_number', 'file_source', 'flash', 'flashpix_version', 'focal_length', 'focal_length_in_35mm_film', 'get', 'get_all', 'get_file', 'get_thumbnail', 'gps_altitude', 'gps_altitude_ref', 'gps_latitude', 'gps_latitude_ref', 'gps_longitude', 'gps_longitude_ref', 'gps_map_datum', 'gps_version_id', 'has_exif', 'image_description', 'jpeg_interchange_format', 'jpeg_interchange_format_length', 'lens_model', 'lens_specification', 'light_source', 'list_all', 'make', 'maker_note', 'max_aperture_value', 'metering_mode', 'model', 'orientation', 'photographic_sensitivity', 'pixel_x_dimension', 'pixel_y_dimension', 'recommended_exposure_index', 'resolution_unit', 'saturation', 'scene_capture_type', 'scene_type', 'sensitivity_type', 'sharpness', 'software', 'user_comment', 'white_balance', 'x_resolution', 'y_and_c_positioning', 'y_resolution']

# %% [markdown]
# __Мы видим значение True у всех объектов и список тегов. Далее удаляем все имеющиеся теги у объектов__

# %%
for k in exif_imgs.keys():
    k.delete_all()
    print(k.has_exif)
# Out:
# True
# /home/alex/bpla/venv/lib/python3.12/site-packages/exif/_image.py:154: RuntimeWarning: could not delete tag <unknown EXIF tag 50341>
#   warnings.warn("could not delete tag " + tag, RuntimeWarning)
# True
# True
# True

# %% [markdown]
# __Как видно, не все теги удалилсь (даже появилось соответсвующее сообщение об ошибке). Однако это связано с тем, что объекты класса exif имеют в качестве тегов не только метаданные, но и служебные методы и функции. Посмотрим, каие теги остались в итоге.__

# %%
for k in exif_imgs.keys():
    print(dir(k))
# Out:
# ['<unknown EXIF tag 50341>', '_exif_ifd_pointer', '_gps_ifd_pointer', '_segments', 'delete', 'delete_all', 'exif_version', 'get', 'get_all', 'get_file', 'get_thumbnail', 'has_exif', 'list_all']
# ['<unknown EXIF tag 50341>', '_exif_ifd_pointer', '_gps_ifd_pointer', '_segments', 'delete', 'delete_all', 'exif_version', 'get', 'get_all', 'get_file', 'get_thumbnail', 'has_exif', 'list_all']
# ['<unknown EXIF tag 50341>', '_exif_ifd_pointer', '_gps_ifd_pointer', '_segments', 'delete', 'delete_all', 'exif_version', 'get', 'get_all', 'get_file', 'get_thumbnail', 'has_exif', 'list_all']
# ['<unknown EXIF tag 50341>', '_exif_ifd_pointer', '_gps_ifd_pointer', '_segments', 'delete', 'delete_all', 'exif_version', 'get', 'get_all', 'get_file', 'get_thumbnail', 'has_exif', 'list_all']

# %% [markdown]
# __Далее необходимо сохранить полученные изображения без тегов в файлы. Как и в предыдущем варианте, создаем новую папку__

# %%
name_pth = 'no_exif_ex'
if not os.path.exists(name_pth):
    os.mkdir(name_pth)
savepth = name_pth

# %% [markdown]
# __Далее в цикле проходим по объектам и сохраняем их__

# %%
# %%time
for k, v in exif_imgs.items():
    with open(os.path.join(savepth, v), 'wb') as new_img:
        new_img.write(k.get_file())
# Out:
# CPU times: user 11.6 ms, sys: 52.8 ms, total: 64.4 ms
# Wall time: 140 ms

# %% [markdown]
# ## Выводы

# %% [markdown]
# Модуль Exif работает намного быстрее,чем Pillow в части удаления тегов. При этом настройки по умолячанию в Pillow значительно изменяют объем изображения, что означает проведенные изменения поимимо удаления метаданных. Этот фактор может повлиять на качество дальнейшей обработки изображения. Поэтому дляудаления метаданных целесообразно использовать модуль EXIF. Однако для Pillow это не основной функционал. Он имеет ограмные возможности, помимо удаления тегов.
