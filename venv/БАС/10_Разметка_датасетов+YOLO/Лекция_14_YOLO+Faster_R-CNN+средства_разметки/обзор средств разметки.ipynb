# %% [markdown]
# ## 1. CVAT (Computer vision annotation tool)
#
# ![image.png](attachment:a116fd1a-aff1-41c3-9192-82e0e3590c64.png)!

# %% [markdown]
# **Ключевая особенность:**
#
# — Полуавтоматическая аннотация
#
# — Интерполяция фигур между ключевыми кадрами
#
# — Дашборд со списком аннотированных проектов и задач
#
# — LDAP
#
# — Поддерживает большое количество инструментов автоматизации, включая автоматическое аннотирование с помощью TensorFlow* Object Detection API или видеоинтерполяции.

# %% [markdown]
# ## 2. VoTT ( Visual Object Tagging Tool)
# ![image.png](attachment:2630e599-6e13-45d1-89d7-f2de9f99bd56.png)

# %% [markdown]
# **Ключевая особенность:**
#
# — Возможность пометить и аннотировать каталоги изображений или отдельные видео.
#
# — Экспорт тегов и ресурсов в формат CNTK, Tensorflow (PascalVOC) или YOLO.
#
# — Предлагает расширяемую модель для импорта/экспорта данных из локальных и облачных хранилищ.
#
# — Позволяет запускать и проверять обученную модель обнаружения объектов CNTK на новых видео для создания более надежных моделей.

# %% [markdown]
# ## 3. LabeIimg
# ![image.png](attachment:9dc74001-19c4-4c09-89b3-1a33b1871530.png)

# %% [markdown]
# **Ключевая особенность:**
#
# — Аннотации сохраняются в виде файлов XML в PASCAL VOC.
#
# — Необходимо установить локально
#
# — Только аннотация изображения
#
# — Только Bounding Box

# %% [markdown]
# ## 4. ImgLab
# ![image.png](attachment:37669d3e-c77d-496b-974b-1e3ed03510d3.png)

# %% [markdown]
# **Ключевая особенность:**
#
# — Имеется как локальная, так и веб-версия
#
# — Основные функции IDE
#
# — Поддерживает несколько типов разметки
#
# — Основные форматы экспорта

# %% [markdown]
# ## 5. Labelme
# ![image.png](attachment:fd64741e-cd32-4b83-b7b5-953926c54d9b.png)

# %% [markdown]
# **Ключевая особенность:**
#
# — Модификация контрольных точек
#
# — Удаление сегментов и полигонов
#
# — Шесть типов аннотации

# %% [markdown]
# # Руководство по работе в VIA версии 2.0.12

# %% [markdown]
# **VGG Image Annotation (VIA)** – браузерный инструмент разметки изображений для
# создания обучающих выборок с открытым исходным кодом, распространяемый по
# лицензии FreeBSD и допускающей свободное использование и производные работы, в
# т.ч. в проприетарном ПО. Основан на html, css и javascript, распространяется в виде
# самостоятельного html-файла, поэтому его работа не зависит от доступа в сеть.
# Отличается простотой графического интерфейса и наличием всех необходимых
# функций разметки для задач:
# - обнаружения (локализация объекта, определение его класса и примерных
# размеров на изображении: разметка вида bounding boxes – ограничивающие
# прямоугольники или другие геометрические примитивы);
# - сегментации (локализация объекта + определение класса + точные контуры
# объекта: разметка вида polygons – полигональные контуры) объектов;
# - “секлетной разметки” (задачи обнаружения фигур и поз) задания ключевых
# точек (landmarks) и ломаных линий (polylines)
# В версии 3 добавлена возможность разметки видео и аудио, а также субтитров

# %% [markdown]
# ![image.png](attachment:60baa64d-a3f0-4eda-86c4-067066bac430.png)

# %% [markdown]
# ## Порядок работы
#
# - 1. Открыть файл VIA (обычно открывается в браузере по умолчанию)

# %% [markdown]
# - 2. Добавить серию изображений для разметки: пункт верхнего меню Project → Add
# local files. В открывшемся диалоге выбрать директорию с файлами, зайти в нее и:
# - выбрать отдельные файлы внутри директории через Ctrl
#
# - выбрать диапазоны файлов «от-до» через Shift
#
# - выбрать все файлы через Ctrl+А
#
# Нажать Open — файлы появятся списком в окне слева

# %% [markdown]
# ![image.png](attachment:4188e00e-7755-4059-b879-1c30ce2f250a.png)

# %% [markdown]
# - 3. Выбрать тип разметки в меню Region Shape вверху-слева, в данном случае — для
# сегментации, т.е. polygons (значок неправльного многоугольника).

# %% [markdown]
# - 4. Если файлы в проекте имеют какие-то важные свойства (атрибуты) в контексте
# задачи — их неоходимо отметить: пункт раскрвающегося меню Attributes слевавнизу, далее выбрать подменю File attributes. Например, для «тюленьего» проекта
# таких файлов явно указано не было и в процессе работы не возникало, хотя иногда их
# удобно группировать по какому-то свойству

# %% [markdown]
# ## Сохранение результатов
# Пункт меню Annotations → Export annotations (as csv) — для сохранения
# результатов в виде текстового файла с запятой в качестве разделителя. Сохраняется
# список имен файлов изображений и для кажого файла координаты всех созданных
# контуров со всеми их свойствами и значениями свойств. Файл с расширением .csv —
# обычный текстовый файл, который можно смиотреть в любом текстовом редакторе,
# но удобнее открывать в Excel, Libre Office и других табличных редакторах.
